# %% [markdown]
# <a href="https://colab.research.google.com/github/TanzilaDewan789/python_all/blob/main/OOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Type of programming
# 1.Imperative 2.Functional 3. Object orianted
#
# #OOP
# Object-Oriented Programming (OOP) in Python is a programming paradigm that organizes code into reusable units called classes and objects.
#
# #Importance of OOP
# 1.Make code more reuseable
#
# 2.Easier to work with large programms
#
# 3.Prevent from repeating code.
#
# 4.Provide security

# %% [markdown]
# #Class
# Class is a blue-print to create an object.
# Example:
# car factory provide Body type of car, tyres, engine type etc.
#
# Class contain 2 types of things-
#
# 1. Attributes - variable defined inside the class
#
# 2. Methods - function defined inside the class

# %%
#class
class Animal:#class
  type = "cat" #attribute

  def sound(self):#method
    print("MewO!")

#Access class.attribute
print(Animal.type)

# To call an instance method, first create an instance of the class
a = Animal()
a.sound()
# Out:
# cat
# MewO!

# %% [markdown]
# #Objects
# Objects are instances of classes. Example- Bike, Ferrari

# %%
class Fruits:#class
  name = "Apple"#attributes


  def details(self):#method
    print("I like fresh green apple")


#creating an object
A = Fruits()
#Accessing the attribute using objects
print(A.name)
#Accessing the method using object
A.details()
# Out:
# Apple
# I like fresh green apple

# %%
class greeting:
  def __init__(self):#__init__ - method(initialize a newly created object) #self -parameter(terget the object location{G})
    print("Hello World!")

greeting()
G = greeting()
# Out:
# Hello World!
# Hello World!

# %%
class Bags_Factory:#Class
  def __init__(self,material, zips,pockets):#methods with blue-prints
    self.material = material #variables for objects (instances)
    self.zips = zips
    self.pockets= pockets
#Objects
Reebok = Bags_Factory("leather",3,2)
Chanel = Bags_Factory("cotton",2,1)

#printing object attributes (object variables)
print(Reebok.material)
print(Reebok.zips)
print(Reebok.pockets)

print(Chanel.material)
# Out:
# leather
# 3
# 2
# cotton

# %%
class Bags_Factory:#Class
  def __init__(self,material, zips,pockets):#methods with blue-prints
    self.material = material #variables for objects (instances)
    self.zips = zips
    self.pockets= pockets

  def show(self):#self = Reebok
    print(f"Your bangs details are materail: {self.material}, zips: {self.zips}, pockets: {self.pockets}")#“go to the object Reebok and get its material”
#Objects
Reebok = Bags_Factory("leather",3,2)


#printing object attributes (object variables)
Reebok.show()
# Out:
# Your bangs details are materail: leather, zips: 3, pockets: 2

# %% [markdown]
# #Attribute & Methods
# Attribute- there are 2 types of attributes
#
# 1. class attributes
#
# 2. Instance attributes
#
# Methodes- there are 3 types of methods
#
# 1. Instance Method:
#
# -Works with object (instance) data
#
#
# -First parameter is always self
#
#
# -Can access and modify instance attributes
#
# 2. Class Method:
#
# -Uses @classmethod decorator
#
# -First parameter is cls
#
# -Can modify class variables
#
# 3. Static Method:
#
# -Uses @staticmethod
#
# -No self or cls
#
# -Works like a normal function inside a class

# %%
class Animal:
  name = "Lion" # class attribute

  def __init__(self, names):
    self.names = names #instance attribute

  def show(self):#Instance Method:
    print(f"Whats your favourite animal? {self.names}")

  @classmethod
  def hello(cls):#Class Method
    print(f"We are learning class methods")

  @staticmethod
  def stat(): #Static Method
    print("We are learning static methods")


obj = Animal("Tiger")
obj.show()#call instance method
obj.hello()#call class method
obj.stat()#call static method
# Out:
# Whats your favourite animal? Tiger
# We are learning class methods
# We are learning static methods
