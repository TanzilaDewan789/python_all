# %% [markdown]
# <a href="https://colab.research.google.com/github/TanzilaDewan789/python_all/blob/main/String.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #String:
# A datatype that stores sequence of characters,

# %% [markdown]
# #Concatenation of string
# combining of string

# %%
print ('Muhammad ibn Musa al-Khwarizmi'+ 'is considered the father of algorithms.')
first_name = "Musa"
last_name = "Khwarizmi"
print(first_name + last_name)
# Out:
# Muhammad ibn Musa al-Khwarizmiis considered the father of algorithms.
# MusaKhwarizmi

# %% [markdown]
# #Escape Sequences

# %%
#(\n) new line

print("Muhammad ibn Musa al-Khwarizmi is considered \n the father of algorithms.")
# Out:
# Muhammad ibn Musa al-Khwarizmi is considered
#  the father of algorithms.

# %%
#(\t) tab
print("Muhammad ibn Musa al-Khwarizmi is considered \t the father of algorithms.")
# Out:
# Muhammad ibn Musa al-Khwarizmi is considered 	 the father of algorithms.

# %% [markdown]
# #Length of string:
# Print your full name and length of the full name.

# %%
name ='Al-Khwarizmi'
print (name)
print (len(name))
# Out:
# Al-Khwarizmi
# 12

# %% [markdown]
# #

# %%
name1 = "Musa"
print(len(name1))
name2 = "Khwarizmi"
print(len(name2))
full_name= name1 + " " + name2
print(full_name)
print(len(full_name))
# Out:
# 4
# 9
# Musa Khwarizmi
# 14

# %% [markdown]
# #Index of string:
# Position of charecter, use to access character
# 1. Positive Index( Left to right) start from 0,1,2,3....9
# 2. Negative Index (Right to left) start from last word of the sentance. -10, -11, -9....1

# %%
fruits = "Apple & Orange"
#what is 4th & last number character
print(fruits[3]) #positive index start from 0
print(fruits[-1])#negative index start backword from -1
# Out:
# l
# e

# %% [markdown]
# #Slicing
# Accessing parts of string

# %%
fruits = "Venus_Earth"
print(fruits[2:5])#Ending index dosen't include
print(fruits[:5]) #[first:5]
print(fruits[5:])#[5:last index]
print(fruits[5:len(fruits)])#[5:last index]
#negative index
print(fruits[-5:-2])
# Out:
# nus
# Venus
# _Earth
# _Earth
# Ear

# %% [markdown]
# #String Function

# %%
#print all the planets name in uppercase
planets = "mercury, venus, earth, mars, jupiter, saturn, uranus, neptune"
print(planets.upper())

#print all the planets name in lowercase
print(planets.lower())
# Out:
# MERCURY, VENUS, EARTH, MARS, JUPITER, SATURN, URANUS, NEPTUNE
# mercury, venus, earth, mars, jupiter, saturn, uranus, neptune

# %%
#Find if the last planets "saturn" or "neptune"?
print(planets.endswith('saturn'))
print(planets.endswith('neptune'))
# Out:
# False
# True

# %%
#Capitalized only 1st starting planet name
print(planets.capitalize())
planets = planets.capitalize()
print(planets)
# Out:
# Mercury, venus, earth, mars, jupiter, saturn, uranus, neptune
# Mercury, venus, earth, mars, jupiter, saturn, uranus, neptune

# %%
#Replace 'earth' to our 'planet'
print(planets.replace('earth','our planet'))
# Out:
# Mercury, venus, our planet, mars, jupiter, saturn, uranus, neptune

# %%
#Find u & count total number of u
print(planets)
print (planets.find('u'))
print(planets.count('u'))
# Out:
# Mercury, venus, earth, mars, jupiter, saturn, uranus, neptune
# 4
# 7
