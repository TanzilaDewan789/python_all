# %% [markdown]
# <a href="https://colab.research.google.com/github/TanzilaDewan789/python_all/blob/main/Variable_Datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1st python program

# %%
print('Hello world')
print("Hello world")
print("""Hello world""")
# Out:
# Hello world
# Hello world
# Hello world

# %%
print('My name is Adam, I am a student')
# Out:
# My name is Adam, i am a student

# %% [markdown]
# # Variable
# (changable/ container): Variable is a container that store data in memory

# %% [markdown]
# Use variable for your name and age, then show output: My name is: Your_name. I am Your_age years old.

# %%
name = "ADAM"
age = 24
print("My name is: ", name, "I am ", age, "years old")
# Out:
# My name is:  ADAM I am  24 years old

# %% [markdown]
# # Data types
# 1.Integer(int) -> 10,20, -10, -20
#
# 2.floot -> 0.3,-0.3
#
# 3.string(str) -> A - Z and a - z (case sensetive language --> a & A both are diff)
#
# 4.boolean -> True and False
#
# 5.none

# %% [markdown]
# show the data types of your name and age.

# %%
name = "ADAM"
age = 24
CGPA = 3.9
print(type(name))
print(type(age))
print(type(CGPA))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# #Operators
# 1.Arithmetic
# 2.Relational
# 3.Assignment
# 4.Logical

# %% [markdown]
# # Arithmetic expression
# Addition, Substraction, Multiplication, Division, Quotient, Remainder, Exponentiation

# %% [markdown]
# Suppose X= 90 and Y= 7, perform all arithmetic operation by using this values.

# %%
x= 90
y = 7

#Addition
add = x+y
print ("Addition is=", add)
# Out:
# Addition is= 97

# %%
#Subtraction
sub = x-y
print ("Subtraction is=", sub)
# Out:
# Subtraction is= 83

# %%
#Multiplication
multi = x*y
print ("Multiplication is=", multi)
# Out:
# Multiplication is= 630

# %%
#Division
div = x/y
print ("Division is=", div)
# Out:
# Division is= 12.857142857142858

# %%
#Quotient
quot = x//y
print ("Quotient is=", quot)
# Out:
# Quotient is= 12

# %%
#Remainder
rem = x%y
print ("Remainder is=", rem)
# Out:
# Remainder is= 6

# %%
#Exponentiation 90^7
exp = x**y
print ("Exponentiation is=", exp)
# Out:
# Exponentiation is= 47829690000000

# %% [markdown]
# #Expression Execution

# %%
a= '2'
b= '3'
c= a+b
print(c)
# Out:
# 23

# %%
a,b= 2,3
c='bob'
print(a*c*b) #(2*bob*3) =6*bob
# Out:
# bobbobbobbobbobbob

# %%
a,b='2',3
c='bob'
print((a+c)*b) # =(('2'+'bob')*3)= '2bob'*3
# Out:
# 2bob2bob2bob

# %%
a,b = 2,3
c= 4
print(a+b*c) # 2+3*4
# Out:
# 14

# %%
a,b = 10, 5.0
print(a*b)
# Out:
# 50.0

# %%
a,b = 1,2
print(a/b)
# Out:
# 0.5

# %%
a,b = 1.5,2
print(a//b) #0.5 --> round and cut after decimal point
# Out:
# 0.0

# %%
#remainder is negative when denominator (b) is negative otherwise possitive
a,b = 5, -2
print (a%b)
# Out:
# -1

# %% [markdown]
# #Relational / comparison operators
#
# equal (==), not equal (!=),  greater than(>),greater than equal(>=),less than (<),less than equal(<=)

# %%
a = 30
b = 20
print (a==b)
print (a!=b)
print (a>b)
print (a<b)
print(a>=b)
print(a<=b)
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# #Assignment operators
# equal (=), increment(+=), dicrement (-=), (*=),(/=), (%=), (**=)

# %%
i= 10

i +=10 # i = i+10 =10 + 10
print (i) #20
# Out:
# 20

# %%
i = 20
i -=10 # i =i-10 = 20- 10
print (i)
# Out:
# 10

# %%
i = 20
i *=10 # i =i*10 = 20*10
print (i)
# Out:
# 200

# %%
i = 20
i /=10 # i =i/10 = 20/10
print (i)
# Out:
# 2.0

# %%
i = 20
i %=10 # i =i%10 = 20 % 10
print (i)
# Out:
# 0

# %%
i = 2
i **=3 # i = i ^ 3 = 2^3
print (i)
# Out:
# 8

# %% [markdown]
# #Logical operators
# not, and , or
#
# not > and > or

# %%
#not : show the opposite value
a = False
print (not a) #True

b=True
print (not b)#False

c=not True #False
print ( not c) #True
# Out:
# True
# False
# True

# %%
#and: when a and b both are True, only then True
a= not False
b = True

print (a and b)
# Out:
# True

# %%
#or : when a and b both are False, only then False
a= False
b = False

print (a or b)
# Out:
# False

# %% [markdown]
# #Type conversion (automatic) & type casting (manual)

# %%
# Type conversion
a= 3.5
b= 2

sum = a+b
print (sum)
# Out:
# 5.5

# %%
# Type casting
a = float ('3.5')
b= 2
print (a+b)
# Out:
# 5.5

# %% [markdown]
# #User input
# Variable_name = variable_type (input ("...."))--->for int and float
# Variable_name =input ("....")--->for string
# print (Variable_name )

# %% [markdown]
# Take a student name, age, email, and student id as input

# %%
name = input("enter your name: ")
print ("Hello,",name)

age = int(input('enter your age:'))
print(age)

email = input('enter your email: ')
print(email)

print(name,"If you are student please enter your student id")

id = int (input('enter your id: '))
print(id)
# Out:
# enter your name: Alex
# Hello, Alex
# enter your age:23
# 23
# enter your email: skdfjjahjh@gmail.com
# skdfjjahjh@gmail.com
# Alex If you are student please enter your student id
# enter your id: 2343443
# 2343443

# %% [markdown]
# #Questions

# %%
#take 3 subjects marks from a student and find the average of their marks
E = int(input('enter your English marks: '))
B = int(input('enter your Bangla marks: '))
M = int(input('enter your Math marks: '))

avg = (E+B+M)//3

print (' Your average marks is= ', avg)
# Out:
# enter your English marks: 78
# enter your Bangla marks: 88
# enter your Math marks: 99
#  Your average marks is=  88

# %%
#Calculate area of a square


a = float(input('enter the side of a square: '))


area_of_a_square = a*a # area_of_a_square = a**2 (a*a & a**2 both are same)
print(area_of_a_square)
# Out:
# enter the side of a square: 4.5
# 20.25
